# %%
from pdf2docx import parse
import os
import shutil
import subprocess
from docx import Document

# %%
def convert_to_docx(path, save_path):
#     ## 原地址
#     path = r"/home/albay/djs/data/Purchase/2023/05/10/"
#     ## 存储地址
#     save_path = r"/home/albay/djs/data/Purchase/2023/05/10/docx/"
    
    if not os.path.exists(save_path):
        os.mkdir(save_path)
    
    for file in os.listdir(path):
        ## 后缀
        suff = os.path.splitext(file)[1]
        
        ## pdf转docx
        if suff == '.pdf': 
            file_name = os.path.splitext(file)[0]
            pdf_file = path + file_name + suff
            docx_file = save_path + file_name + '.docx'
            try:
                parse(pdf_file, docx_file)
            except Exception as e: 
                print("Error: ", e)
        ## doc转docx
        elif suff == '.doc': 
            file_name = os.path.splitext(file)[0]
            doc_file = path + file_name + suff
            os.system("soffice --headless --convert-to docx %s --outdir %s" % (doc_file, save_path))
        ## docx复制到储存地址
        elif suff == '.docx':
            copy_file = path + file
            shutil.copy(copy_file, save_path)
        else: 
            continue

# %%
def recognition(file):    

    #check = ['招标文件', '磋商文件', '项目编号', '项目名称'， '目录'，'文件格式']

    check = '文件格式'
    for para in file.paragraphs: 
        if check in para.text: 
            return True   
    return False
    
#     for i in range(len(file.paragraphs)):
#         print(str(i), file.paragraphs[i].text)
#     for file in os.listdir(path):
#         read_file = path + file

# %%
def recogAll(path, save_path, trash_path):
    ## 读取地址
#     path = r"/home/albay/djs/data/Purchase/2022/12/01/docx/"
#     save_path = r"/home/albay/djs/data/Purchase_2/2022/12/01/"
#     trash_path = r"/home/albay/djs/trash/2022/12/01/"
    
    if not os.path.exists(save_path):
        os.mkdir(save_path)
        
    if not os.path.exists(trash_path):
        os.mkdir(trash_path)
    
    for file in os.listdir(path): 
        try: 
            read_file = Document(path + file)
            tf = recognition(read_file)
            if tf == True: 
                copy_file = path + file
                shutil.copy(copy_file, save_path)
                print("{0} is copied and saved".format(copy_file))
            else:
                copy_file = path + file
                shutil.copy(copy_file, trash_path)
        except Exception as e:
            print('Error: ', e)

# %%
def main():
    date = "2023/05/17/"
    path1 = r"/home/albay/djs/data/Purchase/"
    
    read_path = path1 + date
    save_path =  read_path + "docx/"
    
    path2 = r"/home/albay/djs/data/Purchase_zhaobiao_book/"
    bid_path = path2 + date
    trash_path = r"/home/albay/djs/trash/" + date
    
    print(read_path)
    print(save_path)
    print(bid_path)
    print(trash_path)
    
#     convert_to_docx(read_path, save_path)
    recogAll(save_path, bid_path, trash_path)

# %%
main()
# Out:
# /home/albay/djs/data/Purchase/2023/05/17/
# /home/albay/djs/data/Purchase/2023/05/17/docx/
# /home/albay/djs/data/Purchase_zhaobiao_book/2023/05/17/
# /home/albay/djs/trash/2023/05/17/
# /home/albay/djs/data/Purchase/2023/05/17/docx/8d6000e4c35f3426c9587121a080e5c7.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/468e0388830100206894ec6b7af57242.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/94cd8ca42f066e7ddde15db0cee24b73.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/ee91a548f7de980b90131675e3b3a681.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/e344f9ff77e8c492f01064ef141771e8.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/cf7932c7f19d0e7ba1fc72e7c62d6386.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/935894c7366223d19422f13f2b97a9df.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/a9c75c84b8b9193fb203c58593da5896.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/21f076622e21359bba79c93f05595a18.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/7107692ae0dd90f48ad0ce01c58e1610.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/950463d08befa2c7c949b7f75c47ecd5.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/540abbf5358afd120bf6a2f7da9218f9.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/45aa03df1c28022c19d2422999c7a9ba.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/3d4643b913a0769a5a97fba242046021.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/9fb8933a62c882e54c451896358cb47c.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/8c79d94a69b8240d3036f858869ef373.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/6a7d57ae65fc8bc09dcaa8d73119079f.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/43572acb0c3c7de030f5373c51ddf1c5.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/743a0eef7b670b81bc065508a19dc0f7.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/dcf2e8b9434696b1d52c689e2ac2230b.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/953bccb34a3946c1e5a3d8e3635ce22e.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/9ad5c02ad2ea40d0e4bfc2f22812c664.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/3c25de093c194423a4d2659b4c5dcdd5.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/21bb0ed4872a73322490b27bfe28bf8e.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/5f25c77cc60cce8353d63140189539d2.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/f4af622114fffd4cf753202b3c36d6ee.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/1a4f552fd1136a7e68d71656f5bb14bc.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/6ffc5c28d4f2545645ebb4cc076f2090.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/3af073c1dbe4fd4b9d1f1be02dda7791.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/ecb1711c87161441f6b69272043ec41b.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/30601138aca37d6bd9d99b48872042d8.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/517493c2252e5f78e8200956f665c5a5.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/35ad63619fc57de9e10cf42d85ae62e9.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/0bb0165ddd2e6716bf382da9789847aa.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/14525833bcfaa999bc03b6742a981c2b.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/2bff452cb303edac812104a0816d751c.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/d9f3577c293c19af11fe54c7dd769a35.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/3b72179c8c6e07562b55d682e7589bba.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/d4f0554c5d6bd182cf96cd954cb43bbf.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/c6ff8ed533b10c99562856a5d66cd292.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/f02a580f8ca5c65ab051901b5b75bf03.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/c78de8a24bc2b6c7079e113a936f172f.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/015aba08412bd9da5fcebef915948143.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/3ad3861a9f9ba6c3494d2dc8477db201.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/faa519a96bda585c9e4b42782ec4d7d1.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/023653a904bee5de8d39d452571e5fdc.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/44736c8a6895a7ecd9f15e862e540137.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/8edacaadd810b69255f096a46c957b1e.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/73b29d8919974f152432a83a35a57125.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/9feb8461ad4d16aab6ad7ad59757c9c4.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/26c8bc616cdfaac5ba602e13d7117590.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/ae4370ca66ffdeb73fc082396abb3f1a.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/15828bf8b9b995e8e37ae152c26bca8e.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/8085ef4258c3fd48c669c969274d3924.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/d84b41acdde1ed8c8adcc067fdcc2547.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/ef86e6e2b2065e03b7ec58dd72cdefff.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/2002758b613fa48cfb0df8797ccaf7b2.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/e3a5f099a5d4ac1df87ef367086441af.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/747c4e35adf460464070f2b3c3913308.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/d89f318ebcc4dfcf393c07962d2cc2e8.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/930233b80326d51d329c65cecea27715.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/301f713931936aecf9d44786f84317cd.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/408cbc7c02eed68893b67aa24ac1de28.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/7a36ea7ab7fd45445f80cdd7f5624884.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/e42335d7d2f9a623d5a974400e5f95dd.docx is copied and saved
# /home/albay/djs/data/Purchase/2023/05/17/docx/3a2b4427f72c75ce77bba85fb2b186a5.docx is copied and saved
